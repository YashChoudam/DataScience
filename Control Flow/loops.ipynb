# %%
#For loops
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
sum = 0 
for i in range(1,101):
    sum += i
print(sum)
# Out:
# 5050

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(0,12,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# For loops on string
str="Yash Madhav Choudam"
for i in str:
    print(i)
# Out:
# Y
# a
# s
# h
#
# M
# a
# d
# h
# a
# v
#
# C
# h
# o
# u
# d
# a
# m

# %%
# While loops
count = 0 
while count <=5 :
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Loop control statement
for i in range(1,11,1):
    if (i == 5) :
        continue 
    print(i)
    if(i == 6) :
        break
# Out:
# 1
# 2
# 3
# 4
# 6

# %%
# Pass
for i in range(5):
    if i==3:
        print("hello")
        pass
    print(i)
# Out:
# 0
# 1
# 2
# hello
# 3
# 4

# %%
sum = 0 
for i in range(1,101,1):
    sum += i
print(sum)
# Out:
# 5050

# %%
n = int(input("Enter the number "))
sum = 0 
i = 1 

while i <= n:
    sum = sum + i 
    i += 1
print(sum)
# Out:
# 5050
