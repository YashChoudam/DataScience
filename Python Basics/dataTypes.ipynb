# %% [markdown]
# # Data Types
#  1. Data types are classification of data which tells the compiler or interpreter how the programmer intends to use the data
#  2. They determine the type of operations to be performed on the data , the values that the data can take and the amount of memory needed to store the data
#
# # Basic Data types
#  1. Integers
#  2. Strings
#  3. Booleans
#  4. Floating - point numbers
#
# # Advance Data Types
# 1. Lists
# 2. Tuples
# 3. Sets
# 4. Dictionaries

# %%
a = 10.2 
print(a,type(a))
b = 12
print(b,type(b))
# Out:
# 10.2 <class 'float'>
# 12 <class 'int'>

# %%
a = 10
b = 11 
print((a==b),type(a==b))
# Out:
# False <class 'bool'>

# %%
name = "Yash"
type(name)
# Out:
# str
