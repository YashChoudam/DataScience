# %%
# Arithmetic Opeartions
a = 10 
b = 15 
c = 12
print(a+b+c)
print((a*b)*c)
print((a+b)/c)
print(a%c)
# Out:
# 37
# 1800
# 2.0833333333333335
# 10

# %%
a = 7.8 
b = 7.91

print(a==b)
print(a>b)
print(a<b)
print(b//a)
# Out:
# False
# False
# True
# 1.0

# %%
str1 = "Yash"
str2 = "yash"
print(str1==str2)
print(str1!=str2)
# Out:
# False
# True
