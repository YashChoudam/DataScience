# %%
name = "Yash"
Name = "Choudam"
print(name)
print(Name)
# Out:
# Yash
# Choudam

# %%
age = 20 
if age > 18 :
    print(age)
    
print(age)
# Out:
# 20
# 20

# %%
total = 2 + 4 + 5 + 6 + 7 +\
    8 + 9
print(total)
# Out:
# 41

# %%
## This is single line comment
print("Hello world")
# Out:
# Hello world

# %%
## Multiple statements on the same line 
x = 10 ; y = 19.67 ; z = y / x 
print(x)
print(y)
print(z)
# Out:
# 10
# 19.67
# 1.967

# %%
## understanding semantics 
# variable assignment , in other languages we have to define the data type but in python it is understood by kernel during runtime
name = "YASH"
age = 20 
CGPA = 8.3
print(age,type(age))
print(name,type(name))
print(CGPA,type(CGPA))
# Out:
# 20 <class 'int'>
# YASH <class 'str'>
# 8.3 <class 'float'>

# %%
q = True

if q :
    print("TRUE , inside the if blocl")
    q = False 
    if False :
        print("False , nested if block")
    q = True 
    print("First if")
print("Outside the if block")
# Out:
# TRUE , inside the if blocl
# First if
# Outside the if block
