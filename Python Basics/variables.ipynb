# %%
age = 19
name = "Yash Madhav Choudam"
CGPA = 8.26
is_Student = True 

print("Age : ", age)
print("Name : ", name)
print("CGPA : ", CGPA)
print("IS Student : ", is_Student)
# Out:
# Age :  19
# Name :  Yash Madhav Choudam
# CGPA :  8.26
# IS Student :  True
