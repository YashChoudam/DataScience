# %%
age = 19
name = "Yash Madhav Choudam"
CGPA = 8.26
is_Student = True 

print("Age : ", age)
print("Name : ", name)
print("CGPA : ", CGPA)
print("IS Student : ", is_Student)
# Out:
# Age :  19
# Name :  Yash Madhav Choudam
# CGPA :  8.26
# IS Student :  True

# %%
# Naming Conventions
## Variable name used should be descriptive in nature
## They must start with a letter of an "_" underscore
## It can contain letters numbers and underscores in between
## Case Sensetive in nature

# %%
## Understanding varibales type 
## Python is dynamically typed , type of variable is determined at runtime
age = 20 # Integer
name = "Yash" # String
CGPA = 8.26 # Float
is_student = True # Boolean


## Type conversions

roll = 26 
print(type(roll))
roll_str = str(roll)
print(roll , type(roll))
print(roll_str , type(roll_str))
# print(type(roll_str))
# Out:
# <class 'int'>
# 26 <class 'int'>
# 26 <class 'str'>
